# %% [markdown]
# --- INSTALASI SERPAPI & TEXTBLOB ---

# %%
print(" Menginstal library SerpApi...")
# !pip install google-search-results -q
# !pip install textblob -q
# !python -m textblob.download_corpora -q
# Out:
#  Menginstal library SerpApi...
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package conll2000 to /root/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to /root/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %% [markdown]
# --- LIBRARY ---

# %%
import pandas as pd
from google.colab import drive
from serpapi import GoogleSearch
from textblob import TextBlob
from google.colab import userdata

# %% [markdown]
# --- API KEY ---

# %%
print(" Menyiapkan API Key...")
try:
    API_KEY = userdata.get('API')
except userdata.SecretNotFoundError:
    raise ValueError("API Key tidak ditemukan.")
# Out:
#  Menyiapkan API Key...

# %% [markdown]
# --- ID TARGET (TARGET SCARAPING) ---

# %%
target_data_id = "0x2e7a59e60f698d37:0x22694dc76729e0b5" # Data ID Target
nama_file_output = "semua_ulasan_serpapi.csv"
print(f" Target data_id: {target_data_id}")
# Out:
#  Target data_id: 0x2e7a59e60f698d37:0x22694dc76729e0b5

# %% [markdown]
# --- MULAI SCARAPING ---

# %%
print("\n Melakukan permintaan awal ke SerpApi...")
params = {
    "engine": "google_maps_reviews",
    "data_id": target_data_id,
    "api_key": API_KEY,
    "lang": "id"
}

search = GoogleSearch(params)
results = search.get_dict()

# Inisialisasi list untuk menampung semua ulasan
all_reviews = []

# Cek apakah ada pesan error dari SerpApi sebelum melanjutkan
if "error" in results:
    print(f"\n TERJADI ERROR DARI SERPAPI: {results['error']}")
    print("   -> Pastikan 'data_id' sudah benar dan API Key Anda valid/memiliki kuota.")
else:
    # Jika tidak ada error, baru lanjutkan proses looping (paginasi)
    print(" Permintaan awal berhasil, memulai pengambilan ulasan...")
    page_num = 0

    # Loop ini akan otomatis mengikuti "halaman berikutnya" sampai semua ulasan habis
    while True:
        page_num += 1
        reviews_page = results.get("reviews", [])

        # Kondisi jika halaman pertama kosong meskipun tidak ada error
        if not reviews_page and page_num == 1:
            print("   -> Lokasi ditemukan, namun tidak memiliki ulasan.")
            break

        if not reviews_page:
            print(" Tidak ada ulasan lagi di halaman berikutnya.")
            break

        all_reviews.extend(reviews_page)
        print(f"  -> Halaman {page_num}: Mendapatkan {len(reviews_page)} ulasan. Total sejauh ini: {len(all_reviews)}")

        # Cek apakah ada halaman berikutnya
        if "next_page_token" not in results.get("serpapi_pagination", {}):
            print(" Semua halaman ulasan telah berhasil di-scrape.")
            break

        # Pindah ke halaman berikutnya
        params["next_page_token"] = results.get("serpapi_pagination", {}).get("next_page_token")
        search = GoogleSearch(params)
        results = search.get_dict()
# Out:
# ⏳ Melakukan permintaan awal ke SerpApi...
#  Permintaan awal berhasil, memulai pengambilan ulasan...
#   -> Halaman 1: Mendapatkan 8 ulasan. Total sejauh ini: 8
#   -> Halaman 2: Mendapatkan 10 ulasan. Total sejauh ini: 18
#   -> Halaman 3: Mendapatkan 10 ulasan. Total sejauh ini: 28
#   -> Halaman 4: Mendapatkan 10 ulasan. Total sejauh ini: 38
#   -> Halaman 5: Mendapatkan 10 ulasan. Total sejauh ini: 48
#   -> Halaman 6: Mendapatkan 10 ulasan. Total sejauh ini: 58
#   -> Halaman 7: Mendapatkan 10 ulasan. Total sejauh ini: 68
#   -> Halaman 8: Mendapatkan 10 ulasan. Total sejauh ini: 78
#   -> Halaman 9: Mendapatkan 10 ulasan. Total sejauh ini: 88
#   -> Halaman 10: Mendapatkan 10 ulasan. Total sejauh ini: 98
#   -> Halaman 11: Mendapatkan 10 ulasan. Total sejauh ini: 108
#   -> Halaman 12: Mendapatkan 10 ulasan. Total sejauh ini: 118
#   -> Halaman 13: Mendapatkan 10 ulasan. Total sejauh ini: 128
#   -> Halaman 14: Mendapatkan 10 ulasan. Total sejauh ini: 138
#   -> Halaman 15: Mendapatkan 10 ulasan. Total sejauh ini: 148
#   -> Halaman 16: Mendapatkan 10 ulasan. Total sejauh ini: 158
#   -> Halaman 17: Mendapatkan 10 ulasan. Total sejauh ini: 168
#   -> Halaman 18: Mendapatkan 10 ulasan. Total sejauh ini: 178
#   -> Halaman 19: Mendapatkan 10 ulasan. Total sejauh ini: 188
#   -> Halaman 20: Mendapatkan 10 ulasan. Total sejauh ini: 198
#   -> Halaman 21: Mendapatkan 10 ulasan. Total sejauh ini: 208
#   -> Halaman 22: Mendapatkan 10 ulasan. Total sejauh ini: 218
#   -> Halaman 23: Mendapatkan 10 ulasan. Total sejauh ini: 228
#   -> Halaman 24: Mendapatkan 10 ulasan. Total sejauh ini: 238
#   -> Halaman 25: Mendapatkan 10 ulasan. Total sejauh ini: 248
#   -> Halaman 26: Mendapatkan 10 ulasan. Total sejauh ini: 258
#   -> Halaman 27: Mendapatkan 10 ulasan. Total sejauh ini: 268
#   -> Halaman 28: Mendapatkan 10 ulasan. Total sejauh ini: 278
#   -> Halaman 29: Mendapatkan 10 ulasan. Total sejauh ini: 288
#   -> Halaman 30: Mendapatkan 10 ulasan. Total sejauh ini: 298
#   -> Halaman 31: Mendapatkan 10 ulasan. Total sejauh ini: 308
#   -> Halaman 32: Mendapatkan 10 ulasan. Total sejauh ini: 318
#   -> Halaman 33: Mendapatkan 10 ulasan. Total sejauh ini: 328
#   -> Halaman 34: Mendapatkan 10 ulasan. Total sejauh ini: 338
#   -> Halaman 35: Mendapatkan 10 ulasan. Total sejauh ini: 348
#   -> Halaman 36: Mendapatkan 10 ulasan. Total sejauh ini: 358
#   -> Halaman 37: Mendapatkan 10 ulasan. Total sejauh ini: 368
#   -> Halaman 38: Mendapatkan 10 ulasan. Total sejauh ini: 378
#   -> Halaman 39: Mendapatkan 10 ulasan. Total sejauh ini: 388
#   -> Halaman 40: Mendapatkan 10 ulasan. Total sejauh ini: 398
#   -> Halaman 41: Mendapatkan 10 ulasan. Total sejauh ini: 408
#   -> Halaman 42: Mendapatkan 10 ulasan. Total sejauh ini: 418
#   -> Halaman 43: Mendapatkan 10 ulasan. Total sejauh ini: 428
#   -> Halaman 44: Mendapatkan 10 ulasan. Total sejauh ini: 438
#   -> Halaman 45: Mendapatkan 10 ulasan. Total sejauh ini: 448
#   -> Halaman 46: Mendapatkan 10 ulasan. Total sejauh ini: 458
#   -> Halaman 47: Mendapatkan 10 ulasan. Total sejauh ini: 468
#   -> Halaman 48: Mendapatkan 10 ulasan. Total sejauh ini: 478
#   -> Halaman 49: Mendapatkan 10 ulasan. Total sejauh ini: 488
#   -> Halaman 50: Mendapatkan 10 ulasan. Total sejauh ini: 498
#   -> Halaman 51: Mendapatkan 10 ulasan. Total sejauh ini: 508
#   -> Halaman 52: Mendapatkan 10 ulasan. Total sejauh ini: 518
#   -> Halaman 53: Mendapatkan 10 ulasan. Total sejauh ini: 528
#   -> Halaman 54: Mendapatkan 10 ulasan. Total sejauh ini: 538
#   -> Halaman 55: Mendapatkan 10 ulasan. Total sejauh ini: 548
#   -> Halaman 56: Mendapatkan 10 ulasan. Total sejauh ini: 558
#   -> Halaman 57: Mendapatkan 10 ulasan. Total sejauh ini: 568
#   -> Halaman 58: Mendapatkan 10 ulasan. Total sejauh ini: 578
#   -> Halaman 59: Mendapatkan 10 ulasan. Total sejauh ini: 588
#   -> Halaman 60: Mendapatkan 10 ulasan. Total sejauh ini: 598
#   -> Halaman 61: Mendapatkan 10 ulasan. Total sejauh ini: 608
#   -> Halaman 62: Mendapatkan 10 ulasan. Total sejauh ini: 618
#   -> Halaman 63: Mendapatkan 10 ulasan. Total sejauh ini: 628
#   -> Halaman 64: Mendapatkan 10 ulasan. Total sejauh ini: 638
#   -> Halaman 65: Mendapatkan 10 ulasan. Total sejauh ini: 648
#   -> Halaman 66: Mendapatkan 10 ulasan. Total sejauh ini: 658
#   -> Halaman 67: Mendapatkan 10 ulasan. Total sejauh ini: 668
#   -> Halaman 68: Mendapatkan 10 ulasan. Total sejauh ini: 678
#   -> Halaman 69: Mendapatkan 10 ulasan. Total sejauh ini: 688
#   -> Halaman 70: Mendapatkan 10 ulasan. Total sejauh ini: 698
#   -> Halaman 71: Mendapatkan 10 ulasan. Total sejauh ini: 708
#   -> Halaman 72: Mendapatkan 10 ulasan. Total sejauh ini: 718
#   -> Halaman 73: Mendapatkan 10 ulasan. Total sejauh ini: 728
#   -> Halaman 74: Mendapatkan 10 ulasan. Total sejauh ini: 738
#   -> Halaman 75: Mendapatkan 10 ulasan. Total sejauh ini: 748
#   -> Halaman 76: Mendapatkan 10 ulasan. Total sejauh ini: 758
#   -> Halaman 77: Mendapatkan 10 ulasan. Total sejauh ini: 768
#   -> Halaman 78: Mendapatkan 10 ulasan. Total sejauh ini: 778
#   -> Halaman 79: Mendapatkan 10 ulasan. Total sejauh ini: 788
#   -> Halaman 80: Mendapatkan 10 ulasan. Total sejauh ini: 798
#   -> Halaman 81: Mendapatkan 10 ulasan. Total sejauh ini: 808
#   -> Halaman 82: Mendapatkan 10 ulasan. Total sejauh ini: 818
#   -> Halaman 83: Mendapatkan 10 ulasan. Total sejauh ini: 828
#   -> Halaman 84: Mendapatkan 10 ulasan. Total sejauh ini: 838
#   -> Halaman 85: Mendapatkan 10 ulasan. Total sejauh ini: 848
#   -> Halaman 86: Mendapatkan 10 ulasan. Total sejauh ini: 858
#   -> Halaman 87: Mendapatkan 10 ulasan. Total sejauh ini: 868
#   -> Halaman 88: Mendapatkan 10 ulasan. Total sejauh ini: 878
#   -> Halaman 89: Mendapatkan 10 ulasan. Total sejauh ini: 888
#   -> Halaman 90: Mendapatkan 10 ulasan. Total sejauh ini: 898
#   -> Halaman 91: Mendapatkan 10 ulasan. Total sejauh ini: 908
#   -> Halaman 92: Mendapatkan 10 ulasan. Total sejauh ini: 918
#   -> Halaman 93: Mendapatkan 10 ulasan. Total sejauh ini: 928
#   -> Halaman 94: Mendapatkan 10 ulasan. Total sejauh ini: 938
#   -> Halaman 95: Mendapatkan 10 ulasan. Total sejauh ini: 948
#   -> Halaman 96: Mendapatkan 10 ulasan. Total sejauh ini: 958
#   -> Halaman 97: Mendapatkan 10 ulasan. Total sejauh ini: 968
#   -> Halaman 98: Mendapatkan 10 ulasan. Total sejauh ini: 978
#   -> Halaman 99: Mendapatkan 10 ulasan. Total sejauh ini: 988
#   -> Halaman 100: Mendapatkan 10 ulasan. Total sejauh ini: 998
#   -> Halaman 101: Mendapatkan 10 ulasan. Total sejauh ini: 1008
#   -> Halaman 102: Mendapatkan 10 ulasan. Total sejauh ini: 1018
#   -> Halaman 103: Mendapatkan 10 ulasan. Total sejauh ini: 1028
#   -> Halaman 104: Mendapatkan 10 ulasan. Total sejauh ini: 1038
#   -> Halaman 105: Mendapatkan 10 ulasan. Total sejauh ini: 1048
#   -> Halaman 106: Mendapatkan 10 ulasan. Total sejauh ini: 1058
#   -> Halaman 107: Mendapatkan 10 ulasan. Total sejauh ini: 1068
#   -> Halaman 108: Mendapatkan 10 ulasan. Total sejauh ini: 1078
#   -> Halaman 109: Mendapatkan 10 ulasan. Total sejauh ini: 1088
#   -> Halaman 110: Mendapatkan 10 ulasan. Total sejauh ini: 1098
#   -> Halaman 111: Mendapatkan 10 ulasan. Total sejauh ini: 1108
#   -> Halaman 112: Mendapatkan 10 ulasan. Total sejauh ini: 1118
#   -> Halaman 113: Mendapatkan 10 ulasan. Total sejauh ini: 1128
#   -> Halaman 114: Mendapatkan 10 ulasan. Total sejauh ini: 1138
#   -> Halaman 115: Mendapatkan 10 ulasan. Total sejauh ini: 1148
#   -> Halaman 116: Mendapatkan 10 ulasan. Total sejauh ini: 1158
#   -> Halaman 117: Mendapatkan 10 ulasan. Total sejauh ini: 1168
#   -> Halaman 118: Mendapatkan 10 ulasan. Total sejauh ini: 1178
#   -> Halaman 119: Mendapatkan 10 ulasan. Total sejauh ini: 1188
#   -> Halaman 120: Mendapatkan 10 ulasan. Total sejauh ini: 1198
#   -> Halaman 121: Mendapatkan 10 ulasan. Total sejauh ini: 1208
#   -> Halaman 122: Mendapatkan 10 ulasan. Total sejauh ini: 1218
#   -> Halaman 123: Mendapatkan 10 ulasan. Total sejauh ini: 1228
#   -> Halaman 124: Mendapatkan 10 ulasan. Total sejauh ini: 1238
#   -> Halaman 125: Mendapatkan 10 ulasan. Total sejauh ini: 1248
#   -> Halaman 126: Mendapatkan 10 ulasan. Total sejauh ini: 1258
#   -> Halaman 127: Mendapatkan 10 ulasan. Total sejauh ini: 1268
#   -> Halaman 128: Mendapatkan 10 ulasan. Total sejauh ini: 1278
#   -> Halaman 129: Mendapatkan 10 ulasan. Total sejauh ini: 1288
#   -> Halaman 130: Mendapatkan 10 ulasan. Total sejauh ini: 1298
#   -> Halaman 131: Mendapatkan 10 ulasan. Total sejauh ini: 1308
#   -> Halaman 132: Mendapatkan 10 ulasan. Total sejauh ini: 1318
#   -> Halaman 133: Mendapatkan 10 ulasan. Total sejauh ini: 1328
#   -> Halaman 134: Mendapatkan 10 ulasan. Total sejauh ini: 1338
#   -> Halaman 135: Mendapatkan 10 ulasan. Total sejauh ini: 1348
#   -> Halaman 136: Mendapatkan 10 ulasan. Total sejauh ini: 1358
#   -> Halaman 137: Mendapatkan 10 ulasan. Total sejauh ini: 1368
#   -> Halaman 138: Mendapatkan 10 ulasan. Total sejauh ini: 1378
#   -> Halaman 139: Mendapatkan 10 ulasan. Total sejauh ini: 1388
#   -> Halaman 140: Mendapatkan 10 ulasan. Total sejauh ini: 1398
#   -> Halaman 141: Mendapatkan 10 ulasan. Total sejauh ini: 1408
#   -> Halaman 142: Mendapatkan 10 ulasan. Total sejauh ini: 1418
#   -> Halaman 143: Mendapatkan 10 ulasan. Total sejauh ini: 1428
#   -> Halaman 144: Mendapatkan 10 ulasan. Total sejauh ini: 1438
#   -> Halaman 145: Mendapatkan 10 ulasan. Total sejauh ini: 1448
#   -> Halaman 146: Mendapatkan 10 ulasan. Total sejauh ini: 1458
#   -> Halaman 147: Mendapatkan 10 ulasan. Total sejauh ini: 1468
#   -> Halaman 148: Mendapatkan 10 ulasan. Total sejauh ini: 1478
#   -> Halaman 149: Mendapatkan 10 ulasan. Total sejauh ini: 1488
#   -> Halaman 150: Mendapatkan 10 ulasan. Total sejauh ini: 1498
#   -> Halaman 151: Mendapatkan 10 ulasan. Total sejauh ini: 1508
#   -> Halaman 152: Mendapatkan 10 ulasan. Total sejauh ini: 1518
#  Tidak ada ulasan lagi di halaman berikutnya.

# %% [markdown]
# --- REVIEW SCARPING & SAVE HASIL SCARPING ---

# %%
if all_reviews:
    print("\n Membersihkan dan memformat data ulasan...")

    # Buat list baru untuk menampung data yang sudah bersih
    cleaned_reviews_list = []
    for review in all_reviews:
        cleaned_reviews_list.append({
            'nama_penulis': review.get('user', {}).get('name'), # Akses nama dengan aman
            'rating': review.get('rating'),
            'teks_ulasan': review.get('snippet'),
            'waktu': review.get('date'),
            'likes': review.get('likes', 0)
        })

    # Buat DataFrame dari list yang sudah bersih
    df_final = pd.DataFrame(cleaned_reviews_list)

    # Simpan ke Colab
    df_final.to_csv(nama_file_output, index=False, encoding='utf-8-sig')
    print(f"\n SUKSES! {len(all_reviews)} ulasan telah disimpan dalam file '{nama_file_output}'")

    # Simpan ke Google Drive jika sudah di-mount
    try:
        drive.mount('/content/drive', force_remount=True)
        path_di_drive = f"/content/drive/MyDrive/{nama_file_output}"
        df_final.to_csv(path_di_drive, index=False, encoding='utf-8-sig')
        print(f" SUKSES! Data juga telah disimpan di Google Drive di lokasi: {path_di_drive}")
    except Exception as e:
        print(f"\n Gagal menyimpan ke Google Drive. Error: {e}")

    print("\nBerikut adalah 5 baris pertama data:")
    print(df_final.head())
else:
    print("\n Tidak ada ulasan yang ditemukan atau terjadi kesalahan pada proses sebelumnya.")
# Out:
#  Membersihkan dan memformat data ulasan...
#
#  SUKSES! 1518 ulasan telah disimpan dalam file 'hasil_ulasan_dengan_sentimen.csv'
# Mounted at /content/drive
#  SUKSES! Data juga telah disimpan di Google Drive di lokasi: /content/drive/MyDrive/hasil_ulasan_dengan_sentimen.csv
#
# Berikut adalah 5 baris pertama data:
#         nama_penulis  rating  \
# 0            yussron     5.0
# 1      Bayu Prasetyo     5.0
# 2       Galuh Astika     5.0
# 3       Gayuh Amukti     5.0
# 4  SatriaDarma23 070     5.0
#
#                                          teks_ulasan         waktu  likes
# 0  Recommended to find second laptop like new and...   a month ago      0
# 1          Second laptop recomended secon like a new  3 months ago      0
# 2                                                  👍  2 months ago      0
# 3                                     Recommended 👍🏼  2 months ago      0
# 4  Recommend for all who want to buy newest lapto...   2 years ago      0

# %% [markdown]
# --- MENAMBAHKAN SENTIMEN ---

# %%
path_file_input = "/content/semua_ulasan_serpapi.csv"
nama_kolom_ulasan = 'teks_ulasan'
nama_file_output = 'hasil_ulasan_dengan_sentimen.csv'

print(f"\n Membaca file: {path_file_input}")

try:
    # Baca file CSV ke dalam DataFrame
    df = pd.read_csv(path_file_input)

    # Fungsi untuk analisis sentimen (Case Holding)
    def analisis_sentimen(teks):
        # Memastikan input adalah string
        if not isinstance(teks, str):
            return "Netral"

        # Analisis polaritas. Skor > 0.1 adalah positif, < -0.1 adalah negatif.
        if TextBlob(teks).sentiment.polarity > 0.1:
            return "Positif"
        elif TextBlob(teks).sentiment.polarity < -0.1:
            return "Negatif"
        else:
            return "Netral"

    print(f" Menerapkan analisis sentimen pada kolom '{nama_kolom_ulasan}'...")

    # Terapkan fungsi ke kolom ulasan dan buat kolom baru
    df['case_holding_sentimen'] = df[nama_kolom_ulasan].apply(analisis_sentimen)

    print(" Analisis sentimen selesai.")
    print("\n Berikut adalah 5 baris pertama data dengan kolom baru:")
    print(df.head())

    # Simpan DataFrame yang sudah diperbarui ke file CSV baru
    df.to_csv(nama_file_output, index=False, encoding='utf-8-sig')
    print(f"\n SUKSES! File baru telah disimpan dengan nama '{nama_file_output}'")

    #  Simpan juga hasilnya ke Google Drive
    try:
        drive.mount('/content/drive', force_remount=True)
        path_di_drive = f"/content/drive/MyDrive/{nama_file_output}"
        df_final.to_csv(path_di_drive, index=False, encoding='utf-8-sig')
        print(f" SUKSES! Data juga telah disimpan di Google Drive di lokasi: {path_di_drive}")
    except Exception as e:
        print(f"\n Gagal menyimpan ke Google Drive. Error: {e}")

except FileNotFoundError:
    print(f" ERROR: File '{path_file_input}' tidak ditemukan! Pastikan nama file sudah benar dan file sudah di-upload.")
except KeyError:
    print(f" ERROR: Kolom '{nama_kolom_ulasan}' tidak ditemukan di dalam file CSV! Periksa kembali nama kolom.")
# Out:
#  Membaca file: /content/semua_ulasan_serpapi.csv
#  Menerapkan analisis sentimen pada kolom 'teks_ulasan'...
#  Analisis sentimen selesai.
#
#  Berikut adalah 5 baris pertama data dengan kolom baru:
#         nama_penulis  rating  \
# 0            yussron     5.0
# 1      Bayu Prasetyo     5.0
# 2       Galuh Astika     5.0
# 3       Gayuh Amukti     5.0
# 4  SatriaDarma23 070     5.0
#
#                                          teks_ulasan         waktu  likes  \
# 0  Recommended to find second laptop like new and...   a month ago      0
# 1          Second laptop recomended secon like a new  3 months ago      0
# 2                                                  👍  2 months ago      0
# 3                                     Recommended 👍🏼  2 months ago      0
# 4  Recommend for all who want to buy newest lapto...   2 years ago      0
#
#   case_holding_sentimen
# 0               Positif
# 1                Netral
# 2                Netral
# 3                Netral
# 4                Netral
#
#  SUKSES! File baru telah disimpan dengan nama 'hasil_ulasan_dengan_sentimen.csv'
# Mounted at /content/drive
#  SUKSES! Data juga telah disimpan di Google Drive di lokasi: /content/drive/MyDrive/hasil_ulasan_dengan_sentimen.csv
